# %% [markdown]
# # Welcome to ESS-DIVE's Search Sample Identifiers Jupyter Notebook
#
# This Jupyter Notebook will help data users search ESS-DIVE datasets by Sample Identifiers (IGSN, Sample IDs, Site IDs):
#
#     1. Set Up
#     2. (Optional) Search Using Dataset API
#     3. Search Using DeepDive API
#     4. Visualzing Data
#     5. Download relevant files
#
# Written By: Leo Herrera
#
# Acknowledgements: This notebook builds from Danielle Christianson's Search & Download notebook.

# %% [markdown]
# ## 1. Set Up

# %%
# Set up libraries 
# This notebook requires Python 3.
# ===================================

import csv
import datetime as dt
import io
import json
import os
import pandas as pd
import requests

from ipywidgets import widgets, interact
from IPython.display import display, display_html
from pathlib import Path
from urllib.request import Request, urlopen, urlretrieve
from zipfile import ZipFile


import requests
from io import BytesIO
import pprint
from urllib.parse import urlencode
import numpy as np
pp = pprint.PrettyPrinter(indent=4)


#===================

# %% [markdown]
# ## 1. Set Up/Configure
#
# 1. Go to ESS-DIVE (https://data.ess-dive.lbl.gov/data), login with your ORCID, and copy your authentication token from your account settings page.
# 2. Enter your authentication token into the widget above
# 3. Run the following code cell
#
#    _Always re-run this code cell when you update your token. Tokens expire every 24 hours._
#
# <b> Run this cell and a widget will appear below, paste your ocrid ID authentication token into the widget and move on to the next cell. Do no rerun this cell, or your authentication token will disappear

# %%
my_token = "<put_your_token_here>"
token_text = widgets.Text(my_token, description="Token:")
display(token_text)
# Out:
# Text(value='<put_your_token_here>', description='Token:')

# %%
essdive_api_url = 'http://api.ess-dive.lbl.gov'

essdive_direct_url = 'https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/'

token = token_text.value

# %% [markdown]
# ### Configure local storage for downloads (if desired)
#
# Enter the local directory path in which you want to save downloaded files.

# %%
local_dir = Path('/Users/YLH/ESS-DIVE/essdive-tutorials/downloads')

# ===================================
if local_dir.exists():
    print(f'Success! Local directory {local_dir} configured for downloads')
    print('===================================')
    current_files = [x for x in os.listdir(local_dir) if x != '.DS_Store']
    if current_files:
        print(f'Local directory contains: {current_files}')
    else:
        print(f'Local directory is currently empty.')
else:
    print(f'Cannot find local directory {local_dir}. Please reenter valid directory path.')
    
download_file_log = {}
print('===================================')
print('Downloaded files will be logged in the dictionary object "download_file_log".\n'
      'You can save this dictionary as a file later in the notebook.\n'
      'The filename, file url, and datetime accessed are recorded as a tuple in the "downloaded_files" element.')
# Out:
# Success! Local directory /Users/YLH/ESS-DIVE/essdive-tutorials/downloads configured for downloads
# ===================================
# Local directory contains: ['WHONDRS_YDE22_Data_Package.zip', 'XRF_FTICR_Manuscript_Data_Package.zip', '6_SupplementalData.zip', 'SSS_Ecosystem_Respiration_Data_Package.zip', 'v2_RC2_TemporalStudy_2021_2022_SampleData.zip']
# ===================================
# Downloaded files will be logged in the dictionary object "download_file_log".
# You can save this dictionary as a file later in the notebook.
# The filename, file url, and datetime accessed are recorded as a tuple in the "downloaded_files" element.

# %%
# Run these general functions
# ===================================
        
def assess_datasets_flmd_dd_csv_files(dataset_details_list):
    """
    Find the datasets with flmd files
    Sort the csv file contents into potential and data files; add to the dataset details dictionary
    """
    
    flmd_datasets_indices = set()
    flmd_dataset_details = []
    
    for idx, dataset in enumerate(dataset_details_list):
        file_list = dataset.get('distribution')
    
        flmd_url = {}
        csv_files = {}
        for f in file_list:
            encoding_format = f.get('encodingFormat')
            filename = f.get('name')
            url = f.get('contentUrl')
        
            if 'csv' not in encoding_format or url is None:
                continue
        
            if 'flmd' in filename:
                flmd_datasets_indices.add(idx)
                flmd_url.update({filename: url})
        
            else:
                csv_files.update({filename: url})

        dataset.update({
            'flmd_url': flmd_url,
            'csv_files': csv_files
        })
    
        if not flmd_url:      
            dataset_name = dataset.get('name')
            print(f"No flmd found for dataset: {dataset_name}")
        
    print("=====================================")
    
    if len(flmd_datasets_indices) > 0:
        print(f'flmd found in {len(flmd_datasets_indices)} datasets')
        flmd_dataset_details = [dataset_details_list[x] for x in flmd_datasets_indices]
    else:
        print(f'No datasets in the search results have flmds.')
        
    no_flmd_dataset_details = [dataset_detail for idx, dataset_detail in enumerate(dataset_details_list) if idx not in flmd_datasets_indices]
    
    return flmd_dataset_details, no_flmd_dataset_details


def get_dataset_details(dataset_url):
    
    response_status = None
    try:
        dataset_response = requests.get(dataset_url, headers={"Authorization": f"Bearer {token}"})
        response_status = dataset_response.status_code
    except Exception as e:
        print(f"{dataset.get('dataset').get('name')} did not have a successful return: {e}")
        return None

    # If successful response, add to dataset_store
    if response_status == 200:
            dataset_json = dataset_response.json()['dataset'] 
            print(f"--- Acquired details for {dataset_json.get('name')}")
            return dataset_json
    elif response_status:  
        print(f"Response status {response_status}: {dataset_response.text}")
    else:
        print(f"Response status unavailable. Response cannot be interpreted. Debug required.")
    return None


def get_request(filename, f_url, stream=True):
    """
    Get request for file, and stream the content back
    """

    headers = {'user_agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:77.0) Gecko/20100101 Firefox/77.0',
               'content-type': 'application/json'}
    try:
        r = requests.get(f_url, headers=headers, verify=True, stream=stream)
        status_code = r.status_code
        if status_code == 200:
            return r
        else:
            print(f"{filename} request returned {status_code}")
            return None
    except Exception as e:
        print(f"{filename} request unsuccessful: {e}")
        return None
    
    
def make_store(file_request, use_idx=True, print_headers=True):
    """
    Read response and make store
    """
    file_store = {}
    csv_reader = csv.DictReader(file_request.iter_lines(decode_unicode=True))

    for idx, row in enumerate(csv_reader):
        if use_idx:
            file_store.update({f'Index {idx}': row})
            continue
        fn = row.get('File_Name')
        file_store.update({fn: row})
    
    headers = list(row.keys())
    if print_headers:
        print(f"File headers: {headers}")
    return headers, file_store


def make_pandas_df(file_url, header_rows=1, print_headers=True):
    """
    Read response and make pandas pdf from online csv file
    Designed for ESS-DIVE Sample ID and Metadata RF sample_metadata.csv files that have one header row.
    """
    p_df = pd.read_csv(file_url, skiprows=header_rows)
    
    headers = list(p_df.columns)
    if print_headers:
        print(f"File headers: {headers}")
    return headers, p_df


def inspect_dataset_distribution(dataset_detail, file_type='all'):

    print(dataset_detail.get('name'))
    print('========================================')

    count = 0
    dist = dataset_detail.get('distribution')
    
    for idx, file_info in enumerate(dist):
        fn = file_info.get('name')
        fn_url = file_info.get('contentUrl')
        f_encoding = file_info.get('encodingFormat')
        if file_type != 'all' and file_type not in f_encoding:
            continue
        print(f'Index {idx}: {fn}\n  encoding: {f_encoding}\n  url: {fn_url}')
        count += 1
        
    if count == 0:
        print(f'No files found that match the file_type: "{file_type}" criteria.')
            
            
def retrieve_file_from_essdive(file_url, file_path):
    """ Retrieve the data file 
        file_path includes file name.
    """     
    try:
        urlretrieve(file_url, file_path)
        return True, None
    except Exception as e:
        return False, f'File at url: {file_url} was not saved: {e}'
    

def download_selected_files(dataset_detail, file_indices, file_dir=local_dir, log_store=download_file_log, 
                            is_csv_zipped=False, zip_download=None, zip_member_fn=None):
    dist = dataset_detail.get('distribution')
    ds_id = dataset_detail.get('@id')
    citation = dataset_detail.get('citation')
    ds_name = dataset_detail.get('name')
    
    if log_store is None:
        log_store = {}
    
    log_store.setdefault(ds_id, {'@id': ds_id, 'name': ds_name, 'citation': citation, 'downloaded_files': []})
    ds_file_log = log_store.get(ds_id).get('downloaded_files')
    
    print(f'Saving files in {local_dir}')
    print("-------------------------------------")

    for idx, file_info in enumerate(dist):
        msg = None
        is_downloaded = None
        
        if idx not in file_indices:
            continue
            
        fn = file_info.get('name')
        file_path = local_dir / fn
        fn_url = file_info.get('contentUrl')
        
        if not is_csv_zipped:
    
            download_ts = dt.datetime.now().isoformat()
            is_downloaded, msg = retrieve_file_from_essdive(fn_url, file_path)
    
        else:
            if not zip_download or not zip_member_fn:
                print('ZipFile object and zipped member file name are required. Try again.')
                return None
            try:
                zip_download.extract(zip_member_fn, path=file_path)
                if Path.exists(file_path / zip_member_fn):
                    is_downloaded = True
                    download_ts = dt.datetime.now().isoformat()
                else:
                    msg = f'Extraction of {zip_member_fn} from {fn} was not successful.'
            except Exception as e:
                msg = f'ERROR attempting to extract {zip_member_fn} from {fn}: {e}'
        
        if is_downloaded:
            print(f'--- {fn} downloaded')
            ds_file_log.append((fn, fn_url, download_ts))
        else:
            print(msg)
            
    print("-------------------------------------")
    print(f'Remember to cite these files! Dataset DOI {ds_id}')
    return ds_id    


def inspect_zip_file_contents(dataset_detail, file_idx):
    dist = dataset_detail.get('distribution')
    file_info = dist[file_idx]
    
    if not file_info:
        print('File index not found. Please try again.')
        return
    
    fn = file_info.get('name')
    if 'zip' not in file_info.get('encodingFormat'):
        print(f'{fn} is not encoded as a zip file. Please select a different file.')
    
    fn_url = file_info.get('contentUrl')
    resp = urlopen(fn_url)
    
    zip_download = ZipFile(io.BytesIO(resp.read()))
    
    print(f'{fn} contents:')
    print('=================================')
    for idx, file_member in enumerate(zip_download.namelist()):
        print(f'Index {idx}: {file_member}')
        
    return fn, zip_download


def read_zipped_csv(zip_file_obj, csv_file_name, header_rows=1):
    #with open(zip_file_obj, mode='r') as z:
    #     csv_df = pd.read_csv(io.BytesIO(z.read(csv_file_name)))
    csv_df = pd.read_csv(zip_download.open(csv_file_name),encoding='windows-1254', skiprows=header_rows)
    return csv_df
    
    
print('Functions loaded.')

#-------------------------------------------
def in_deep_dive(doi):
    params  = {}
    params['rowStart'] = 1
    params['pageSize'] = 100
    params['doi'] = doi
    
    query_string=urlencode(params)

    r = requests.get(f"https://fusion.ess-dive.lbl.gov/api/v1/deepdive?{query_string}")
    if r.status_code == 200:
        results = r.json()['results']
        if not results:
            return False
        return True
    else:
        print("ERROR")
        print(r.text)
        return None

def search_datasets(go):
    header_authorization =  f"bearer {token}"
    response = requests.get(get_packages_response, headers={"Authorization": header_authorization})

    if response.status_code == 200:
        # Success
        global response_json 
        response_json = response.json()
        print("Success! Continue to look at the search results")  
        go = True
        return go
    else:
        # There was an error
        print("There was an error. Stop here and debug the issue. Email ess-dive-support@lbl.gov if you need assistance. \n")
        print(response.text)
        
def view_search_results():
    search_record_total = response_json['total']
    print(f"Datasets found: {search_record_total}")

    if search_record_total > 100:
        print("The search API cannot return more than 100 results at a time. See documentation for how to paginate.")

    canidate_datasets = response_json['result']


    for idx, dataset in enumerate(canidate_datasets):
        print('________________')
        print(f'Index: {idx}')
        print(dataset.get('dataset').get('name'))
        print(dataset.get('viewUrl'))
        print(dataset.get('dataset').get('datePublished'))

        if in_deep_dive(dataset.get('viewUrl')[35:]):
            print('In the DeepDive!')
            
def construct_query(essdive_api_url, text=None, keywords=None, providerName=None, creator=None, datePublished=None, rowStart=None, pageSize=None):
    # Default values for rowStart and pageSize if None
    rowStart = 1 if rowStart is None else rowStart
    pageSize = 100 if pageSize is None else pageSize

    # Start constructing the query
    query = f"{essdive_api_url}/packages?rowStart={rowStart}&pageSize={pageSize}&text={text}&isPublic=true"

    # Add additional parameters if they are not None
    if text is not None:
        query += f"&text={text}"
    if keywords is not None:
        query += f"&keywords={keywords}"
    if providerName is not None:
        query += f"&providerName={providerName}"
    if creator is not None:
        query += f"&creator={creator}"
    if datePublished is not None:
        query += f"&datePublished={datePublished}"

    return query

def extract_csv_names_and_urls(data):
    """
    Extracts CSV file names and their URLs from a dataset dictionary.

    Parameters:
    - data: A dictionary containing dataset information including distributions.

    Returns:
    - A dictionary with CSV file names as keys and their content URLs as values.
    """
    # Initialize an empty dictionary to hold the CSV file names and URLs
    csv_files = {}
    
    # Check if 'distribution' key is in the data and it is a list
    if 'distribution' in data and isinstance(data['distribution'], list):
        # Loop through each item in the distribution list
        for item in data['distribution']:
            # Check if the item is a dictionary with 'encodingFormat' and 'contentUrl' keys
            # and if the encodingFormat indicates a CSV file
            if isinstance(item, dict) and 'encodingFormat' in item and item.get('encodingFormat') == 'text/csv':
                # Add the CSV file name and its URL to the dictionary
                csv_files[item['name']] = item['contentUrl']
    
    return csv_files
            
def find_common_elements(array1, array2):
    common_elements = []
    for element in array1:
        if element in array2:
            common_elements.append(element)
    return common_elements

def find_unique_elements(array1, array2):
    unique_elements = []
    for element in array1:
        if element not in array2:
            unique_elements.append(element)
    return unique_elements

def remove_duplicates(arr):
    # Initialize an empty list to store unique subarrays
    unique_subarrays = []
    
    # Iterate through the array
    for subarray in arr:
        # Check if the subarray is already present in the list of unique subarrays
        if subarray not in unique_subarrays:
            unique_subarrays.append(subarray)
    
    return unique_subarrays


def combine_arrays(arr1, arr2):
    # Check if the arrays have the same length
    if len(arr1) != len(arr2):
        return "Arrays must have the same length"
    
    # Initialize an empty list to store combined arrays
    combined_arr = []
    
    # Iterate over the arrays and combine corresponding elements
    for i in range(len(arr1)):
        combined_arr.append([arr1[i], arr2[i]])
    
    return combined_arr

def search_array(arr, target):
    # Iterate through the array
    for i, item in enumerate(arr):
        # Check if the current item matches the target string
        if item == target:
            # Return the index of the target string
            return i
    
    # If the target string is not found, return None
    return None
    print("Error, no matching value found in the array.")

def slice_string(string):
    # Split the string by "/"
    parts = string.split("/")
    
    # Get the part of the string after the last "/"
    if len(parts) > 1:
        result = parts[-1]
    else:
        result = string
    
    return result

def slice_series(series):
    # Use the .str accessor to apply string manipulation
    result = series.str.split("/").str[-1]
    return result

def get_string_before_first_slash(input_string):
    # Split the string by '/' and get the first part
    parts = input_string.split('/', 1)
    return parts[0]

def get_string_after_first_slash(s):
    """
    Returns the substring that appears after the first slash in the input string.
    If there is no slash, returns the entire string.
    
    :param s: Input string
    :return: Substring after the first slash or the entire string if no slash is found.
    """
    # Split the string using slash as the delimiter
    parts = s.split('/', 1)  # The '1' argument makes split return two parts at most

    # Check if the string was split into two parts
    if len(parts) > 1:
        return parts[1]  # Return the part after the first slash
    else:
        return s  # Return the original string if there is no slash

# Function to handle button click
def on_button_clicked(b):
    # Using the current value of the number widget as a parameter for the function
    display_file(index_widget.value, df)

def display_file(index, df):
    #get dataset details
    dataset_details_url = f'https://api.ess-dive.lbl.gov/packages/{df["version"][index]}'
    response_status = None
    try:
        dataset_response = requests.get(dataset_details_url, headers={"Authorization": f"Bearer {token}"})
        response_status = dataset_response.status_code
    except Exception as e:
        print(f"{dataset.get('dataset').get('name')} did not have a successful return: {e}")
        return None

    # If successful response, add to dataset_store
    if response_status == 200:
            dataset_json = dataset_response.json()['dataset'] 
            #print(f"--- Acquired details for {dataset_json.get('name')}")
            dataset_details = dataset_json
    elif response_status:  
        print(f"Response status {response_status}: {dataset_response.text}")
        dataset_details = None
    else:
        print(f"Response status unavailable. Response cannot be interpreted. Debug required.")
        dataset_details = None
    
    if not dataset_details:
        print(f"{dataset.get('dataset').get('name')} did not have a successful return: {e}")
        return None
    
    #inspect dataset
    
    #count = 0
    file_names = []
    dist = dataset_details.get('distribution')
    for idx, file_info in enumerate(dist):
        fn = file_info.get('name')
        file_names.append(fn)

    
    #matches the index with the file you searched for
    file_index = None
    try:
        file_index = file_names.index(get_string_before_first_slash(df['data_file'][index]))
    except ValueError:
        print(f"'{get_string_before_first_slash(df['data_file'][index])}' is not in the datafile list.") 
        print("There was an error, move on to the next section.")
    
    # unzip if zip is there 
    zip_file_idx = file_index
    dist = dataset_details.get('distribution')
    file_info = dist[zip_file_idx]
    if not file_info:
        print('File index not found. Please try again.')
        return
    
    fn = file_info.get('name')
    if 'zip' not in file_info.get('encodingFormat'):
        print(f'{fn} is not encoded as a zip file. Please select a different file.')
    
    fn_url = file_info.get('contentUrl')
    resp = urlopen(fn_url)
    
    zip_download = ZipFile(io.BytesIO(resp.read()))
    csv_file_index = zip_download.namelist().index(get_string_after_first_slash(df['data_file'][index]))
    
    pd.set_option('display.max_columns', None)
    pd.set_option('display.max_rows', None)
    
    header_rows = 0

    # ===================================
    csv_file_name = zip_download.namelist()[csv_file_index]
    print(f'Attempting to read: {csv_file_name} from zip file {fn}')
    print('=============================================================================')
    
    metadata_df = pd.read_csv(zip_download.open(csv_file_name),encoding='windows-1254', skiprows=header_rows)

    
    # check if metadata is at the top of the file
    if list(metadata_df.columns.values)[0].startswith("#"):
        header_rows = 1
        print("Addtional Information:", list(metadata_df.columns.values)[0][1:])
        metadata_df = pd.read_csv(zip_download.open(csv_file_name),encoding='windows-1254', skiprows=header_rows)

    if metadata_df is not None:
        is_csv_zipped = True
        headers = list(metadata_df.columns)
        display(metadata_df)
    else:
        print('ERROR: Sample metadata file was not successfully loaded.')
# Out:
# Functions loaded.

# %% [markdown]
# # 2. (Optional) Search using Dataset API
#
#     Pros: The Dataset API can access more datasets within ESS-DIVE
#
# ### Check if your sample identifer is in the metadata of any dataset in ESS-DIVE
# Use the ESS-DIVE Dataset API to search for datasets of interest.
#
# You can search for datasets using any of the following parameters:
# - Dataset Creator (creator)
# - Date Published (datePublished)
# - Project Name (providerName)
# - Any text (text)
# - Keywords (keywords)
# - Public datasets only (isPublic)
#
# **See additional details for dataset search in the ESS-DIVE package API techincal documentation:**** https://api.ess-dive.lbl.gov/#/Data%20Package/listPackages.
#
# Use the [ESS-DIVE's project list](https://docs.google.com/spreadsheets/d/179SOyv42wXbP4owWZtUg3RqhW9dPOyENYcVYuUCcqwg/edit?usp=sharing) to find the options for project names.

# %%
#The default search uses the IGSN 10.15485/1729719 as an example. If you'd like to change the search text 
#change the value of `text` to your desired search term

# For an exact match, put the string in quotes, e.g. "\"10.15485/1729719\"" is an exact match, 
# "10.15485/1729719" is any match




# More search examples 
#===========================================================
#text = "*IEWDR00OJ" # * will perform a wildcard search  
#text = "*IEWFS0002"
#text = "*1729719"
#text = "IGSN"
#text = "\"W20\"" #(Site ID)

text= "*IEWFS0002"

# %%
#If you'd like to search using these paramters replace None.
keywords = None
providerName = None
creator = None
datePublished = None  # "<[YYYY TO YYYY-MM-DD]>" # Not the same as data coverage 
#Ensure None is assigned to search parameters you do not want to search with.
# ==========================================================
rowStart = 1
pageSize = 100

get_packages_response = construct_query(essdive_api_url,text,keywords,providerName,creator,datePublished,rowStart,pageSize)

go = False
go = search_datasets(go)
if go:
    view_search_results()
# Out:
# Success! Continue to look at the search results
# Datasets found: 2
# ________________
# Index: 0
# Soil Nitrogen, Water Content, Microbial Biomass, and Archaeal, Bacterial and Fungal Communities from the East River Watershed, Colorado collected in 2016-2017
# https://data.ess-dive.lbl.gov/view/doi:10.15485/1577267
# 2019
# ________________
# Index: 1
# Sample Collection Metadata for Soil Cores from the East River Watershed, Colorado collected in 2017
# https://data.ess-dive.lbl.gov/view/doi:10.21952/WTR/1573029
# 2019

# %% [markdown]
# # 3. Search using the Deep-Dive API
#
# ### Put a Sample Identifier (IGSN/Sample ID/Site ID) of interest in the Field Value box

# %%
#  Search examples:  method, latitude, sample, stream
field_name = widgets.Text(
    value='',
    description='Field Name:',
    disabled=False
)
doi = widgets.Text(
    value='',
    description='DOI:',
    disabled=False
)
field_value_text = widgets.Text(
    value='',
    description='Field Value Text',
    disabled=False
)

display(field_value_text)

# example searches

# Field Value Text = S22RR (Site ID)
# Field Value Text = S19S_0037 (Sample ID)
# Field Value Text = 10.58052/IEPRS00CY (IGSN) 
# Field Value Text = 10.58052/IEWDR01TV (IGSN)
# doi = doi:10.15485/2246724
# doi = doi:10.15485/2204421

# NOTE: Once your search term is inputed, do not rerun the code or your inputs will disappear
# Out:
# Text(value='', description='Field Value Text')

# %% [markdown]
# ### If you see an a dataset from the results above says "In the Deep Dive!" you can search for it here. Uncomment display(doi) by removing the '#' in front of it. Rerun the code and the widget will appear. <br>
# (Note) When searching by doi follow this format: doi:10.15485/1824222

# %%
#=================================
# Uncomment the lines below if you'd like to search by differnet parameters

#display(field_name) #Search by header names
display(doi)

#doi:10.15485/2204421 #CSV only dataset, no zip
# Out:
# Text(value='', description='DOI:')

# %% [markdown]
# ## Run this code to see the results of your Deep Dive search
# This cell is displaying all the datafiles in which your search term appears.
#
# ### Use the display button to quickly look within files and check if data is relevant.
# - Change the index to match the datafile you want to look inside of.
# - If too many files are being displayed rerun this block of code to remove them.

# %%
# Query by field name
# Case-insensitive search 
params  = {}
params['rowStart'] = 1
params['pageSize'] = 25
if doi.value:
    params['doi'] = doi.value
    print("Searching for: ", doi.value)
if field_name.value:
    params['fieldName']  = field_name.value
    print("Searching for: ", field_name.value)
if field_value_text.value:
    params['fieldValueText']  = field_value_text.value
    print("Searching for: ", field_value_text.value)

query_string=urlencode(params)
#Uncomment to see query string
#print(query_string)


# Creating the number widget
index_widget = widgets.IntText(value=0, description='Index:', disabled=False)
button = widgets.Button(description="Display File")
button.on_click(on_button_clicked)
widgets.HBox([button, index_widget]) #Displaying the button and number widget next to each other
display(widgets.HBox([button, index_widget]))

r = requests.get(f"https://fusion.ess-dive.lbl.gov/api/v1/deepdive?{query_string}")
if r.status_code == 200:
    # Look at search results
    results = r.json()['results']
    df = pd.read_json(json.dumps(results))
    display(df)

else:
    print("ERROR")
    print(r.text)
# Out:
# Searching for:  doi:10.15485/2204421
# HBox(children=(Button(description='Display File', style=ButtonStyle()), IntText(value=0, description='Index:')…
#                          field_name                   unit  \
# 0                          Latitude  decimal_degrees_WGS84
# 1                         Longitude  decimal_degrees_WGS84
# 2             InstallationMethod_ID                    N/A
# 3    InstallationMethod_Description                    N/A
# 4                          DateTime    YYYY-MM-DD hh:mm:ss
# 5                          Latitude  decimal_degrees_WGS84
# 6                         Longitude  decimal_degrees_WGS84
# 7            Deep_Water_Temperature        degrees_celsius
# 8         Surface_Water_Temperature        degrees_celsius
# 9      Deep_Electrical_Conductivity    microsiemens_per_cm
# 10  Surface_Electrical_Conductivity    microsiemens_per_cm
# 11                      Rn_222_Mean   picocuries_per_liter
# 12                        Rn_222_SD   picocuries_per_liter
# 13                       Rn_222_Min   picocuries_per_liter
# 14                       Rn_222_Max   picocuries_per_liter
# 15                     Rn_222_Notes                    N/A
# 16                   Rn_222_Quality                    N/A
# 17                         DateTime    YYYY-MM-DD hh:mm:ss
# 18                         Latitude  decimal_degrees_WGS84
# 19                        Longitude  decimal_degrees_WGS84
# 20           Deep_Water_Temperature        degrees_celsius
# 21        Surface_Water_Temperature        degrees_celsius
# 22     Deep_Electrical_Conductivity    microsiemens_per_cm
# 23  Surface_Electrical_Conductivity    microsiemens_per_cm
# 24                      Rn_222_Mean   picocuries_per_liter
#
#                                            definition  data_type  \
# 0                     Latitude of sensor measurement.        NaN
# 1                    Longitude of sensor measurement.        NaN
# 2   Unique user-determined ID for a method listed ...        NaN
# 3   Free text field to describe the sensor install...        NaN
# 4   Date and time of measurement. UTC offset is re...        NaN
# 5                     Latitude of sensor measurement.        NaN
# 6                    Longitude of sensor measurement.        NaN
# 7           Temperature of water just above riverbed.        NaN
# 8   Temperature of water just below the river surf...        NaN
# 9   Electrical conductivity of water just above th...        NaN
# 10  Electrical conductivity of water just below lh...        NaN
# 11  Arithmetic mean of the radon concentrations re...        NaN
# 12  Standard deviation of the radon concentrations...        NaN
# 13  Lowest radon concentration recorded during the...        NaN
# 14  Highest radon concentration recorded during th...        NaN
# 15  Notes recorded during processing of the Rn-222...        NaN
# 16  Quality flag indicating whether radon samples ...        NaN
# 17  Date and time of measurement. UTC offset is re...        NaN
# 18                    Latitude of sensor measurement.        NaN
# 19                   Longitude of sensor measurement.        NaN
# 20          Temperature of water just above riverbed.        NaN
# 21  Temperature of water just below the river surf...        NaN
# 22  Electrical conductivity of water just above th...        NaN
# 23  Electrical conductivity of water just below lh...        NaN
# 24  Arithmetic mean of the radon concentrations re...        NaN
#
#     total_record_count  missing_values_count  \
# 0                    4                     0
# 1                    4                     0
# 2                    4                     0
# 3                    4                     0
# 4                46138                     0
# 5                46138                     0
# 6                46138                     0
# 7                46138                     0
# 8                46138                     0
# 9                46138                     0
# 10               46138                     0
# 11               46138                     0
# 12               46138                     0
# 13               46138                     0
# 14               46138                     0
# 15               46138                     0
# 16               46138                     0
# 17               67113                     0
# 18               67113                     0
# 19               67113                     0
# 20               67113                     0
# 21               67113                     0
# 22               67113                     0
# 23               67113                     0
# 24               67113                     0
#
#                                        values_summary                   doi  \
# 0                               {'unique': ['-9999']}  doi:10.15485/2204421
# 1                               {'unique': ['-9999']}  doi:10.15485/2204421
# 2   {'unique': ['Tow_01', 'Tow_02', 'Tow_03', 'Tow...  doi:10.15485/2204421
# 3   {'unique': ['Sensor towed from boat along the ...  doi:10.15485/2204421
# 4                                                None  doi:10.15485/2204421
# 5                                                None  doi:10.15485/2204421
# 6   {'unique': ['-119.3426', '-119.2598', '-119.35...  doi:10.15485/2204421
# 7   {'unique': ['2.63617', '2.64566', '2.6443', '2...  doi:10.15485/2204421
# 8   {'unique': ['2.88638', '2.91352', '2.89453', '...  doi:10.15485/2204421
# 9                                                None  doi:10.15485/2204421
# 10                                               None  doi:10.15485/2204421
# 11  {'unique': ['13.79092277', '26.14086121', '8.0...  doi:10.15485/2204421
# 12  {'unique': ['11', '37.7', '12.8', '9.55', '18....  doi:10.15485/2204421
# 13  {'unique': ['19.0', '0.0', '0', '19', '-9999.0...  doi:10.15485/2204421
# 14  {'unique': ['76.5', '110.0', '88.4', '76.1', '...  doi:10.15485/2204421
# 15  {'unique': ['N/A', 'analysis time change to MS...  doi:10.15485/2204421
# 16                    {'unique': ['-9999', '1', '0']}  doi:10.15485/2204421
# 17                                               None  doi:10.15485/2204421
# 18                                               None  doi:10.15485/2204421
# 19  {'unique': ['-119.7439', '-119.7438', '-119.74...  doi:10.15485/2204421
# 20  {'unique': ['19.61719', '19.61526', '19.61693'...  doi:10.15485/2204421
# 21                                               None  doi:10.15485/2204421
# 22                                               None  doi:10.15485/2204421
# 23                                               None  doi:10.15485/2204421
# 24  {'unique': ['2.109428621', '4.213505636', '3.0...  doi:10.15485/2204421
#
#                                         version                data_file  \
# 0   ess-dive-d118621673376b6-20231031T065920243  InstallationMethods.csv
# 1   ess-dive-d118621673376b6-20231031T065920243  InstallationMethods.csv
# 2   ess-dive-d118621673376b6-20231031T065920243  InstallationMethods.csv
# 3   ess-dive-d118621673376b6-20231031T065920243  InstallationMethods.csv
# 4   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 5   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 6   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 7   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 8   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 9   ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 10  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 11  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 12  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 13  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 14  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 15  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 16  ess-dive-d118621673376b6-20231031T065920243    February2021_Data.csv
# 17  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 18  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 19  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 20  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 21  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 22  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 23  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
# 24  ess-dive-d118621673376b6-20231031T065920243        July2021_Data.csv
#
#                                         data_file_url
# 0   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 1   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 2   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 3   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 4   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 5   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 6   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 7   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 8   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 9   https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 10  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 11  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 12  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 13  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 14  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 15  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 16  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 17  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 18  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 19  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 20  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 21  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 22  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 23  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...
# 24  https://fusion.ess-dive.lbl.gov/api/v1/deepdiv...

# %% [markdown]
# # 3. List File Names that Include the Identifer you Searched For

# %%
#sample_id_dois = np.array(df['doi'])
dataset_id = np.array(df['version'])
data_file_name = np.array(slice_series(df['data_file']))

combined_array = combine_arrays(dataset_id, data_file_name)
combined_array = remove_duplicates(combined_array)

#LH edit this print
print("                  This is the file identifer:                        This is the filename:")

for i, item in enumerate(combined_array):
    #print file identifier
    print(f"Index: {i}", item)
# Out:
#                   This is the file identifer:                        This is the filename:
# Index: 0 ['ess-dive-d118621673376b6-20231031T065920243', 'InstallationMethods.csv']
# Index: 1 ['ess-dive-d118621673376b6-20231031T065920243', 'February2021_Data.csv']
# Index: 2 ['ess-dive-d118621673376b6-20231031T065920243', 'July2021_Data.csv']

# %% [markdown]
# ### Get dataset title and file information

# %%
#change the combined array index to match the dataset you're interested in
dataset_index = 1

#=======================
dataset_id = combined_array[dataset_index][0]
#dataset_id = 'ess-dive-2569191b32b447d-20230809T173212651'
# Find dataset identifier from search above or via Search Webpage
dataset_details_url = f'https://api.ess-dive.lbl.gov/packages/{dataset_id}'



dataset_detail = get_dataset_details(dataset_details_url)
inspect_dataset_distribution(dataset_detail, 'all')
# Out:
# --- Acquired details for Riverbed and Near-Surface Water Quality Data, Hanford Reach, Columbia River, February 2021 - April 2022
# Riverbed and Near-Surface Water Quality Data, Hanford Reach, Columbia River, February 2021 - April 2022
# ========================================
# Index 0: April2022_HoleData.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-505312ec069ddd0-20231031T065654531
# Index 1: February2021_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-b66e5f0539585dd-20231031T065654543
# Index 2: April2022_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-387425f9b98db53-20231031T065654523
# Index 3: InstallationMethods.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-8baedb632fa881d-20231031T065654549
# Index 4: July2021_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-cb03bbf00138398-20231031T065654559
# Index 5: FLMD.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-0676459a454fc11-20231031T065654546
# Index 6: dd.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-9b114a25948bdcb-20231031T065654539
# Index 7: Riverbed_and_Near_Surface_Water_Quality_Data_.xml
#   encoding: https://eml.ecoinformatics.org/eml-2.2.0
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-d118621673376b6-20231031T065920243

# %% [markdown]
# ## View dataset CSV files
# ### If no CSV file found move down to the section 3.5

# %%
# ==============================================
csv_files = extract_csv_names_and_urls(dataset_detail)

if not csv_files:
    print('No csv files. Try Zip File Option below.')

csv_index = []
idx = 0
for fn, url in csv_files.items():
    print(f'Index {idx}: {fn}\n{url}')
    csv_index.append(fn)
    idx += 1
# Out:
# Index 0: April2022_HoleData.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-505312ec069ddd0-20231031T065654531
# Index 1: February2021_Data.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-b66e5f0539585dd-20231031T065654543
# Index 2: April2022_Data.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-387425f9b98db53-20231031T065654523
# Index 3: InstallationMethods.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-8baedb632fa881d-20231031T065654549
# Index 4: July2021_Data.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-cb03bbf00138398-20231031T065654559
# Index 5: FLMD.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-0676459a454fc11-20231031T065654546
# Index 6: dd.csv
# https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-9b114a25948bdcb-20231031T065654539

# %% [markdown]
# ### Select and load the sample metadata csv file

# %%
metadata_file_idx = 5
# ==================================
# get file_url
fn = csv_index[metadata_file_idx]
fn_url = csv_files.get(fn)

if not fn_url:
    print('Something is amiss! Could not find file_url. Try again.')
else:
    try:
        headers, metadata_df = make_pandas_df(fn_url, print_headers=False)
        print(f'{fn} was loaded as a pandas dataframe.')
        display(metadata_df)
    except Exception as e:
        print(f'Error while attempted to read the {fn_url} into a pandas dataframe. Try again.\nError: {e}')
# Out:
# FLMD.csv was loaded as a pandas dataframe.
#                   FLMD.csv       File-level metadata associated with dataset.
# 0                   dd.csv  Data dictionary defining column headers and ot...
# 1  InstallationMethods.csv  Description of methods associated with install...
# 2    February2021_Data.csv  This file contains all data collected during t...
# 3        July2021_Data.csv  This file contains all data collected during t...
# 4       April2022_Data.csv  This file contains the longitudinal profiles c...
# 5   April2022_HoleData.csv  This file contains the additional data collect...

# %% [markdown]
# # 3.5 Zip File
# ### The file you're interested in might be in a zip file. Run cell to unzip files.

# %%
# Run if sample_metadata csv file is not found

# ===================================
inspect_dataset_distribution(dataset_detail, 'all') 
file_names = []
dist = dataset_detail.get('distribution')
for idx, file_info in enumerate(dist):
    fn = file_info.get('name')
    file_names.append(fn)
# Out:
# Riverbed and Near-Surface Water Quality Data, Hanford Reach, Columbia River, February 2021 - April 2022
# ========================================
# Index 0: InstallationMethods.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-8baedb632fa881d-20231031T065654549
# Index 1: dd.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-9b114a25948bdcb-20231031T065654539
# Index 2: February2021_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-b66e5f0539585dd-20231031T065654543
# Index 3: April2022_HoleData.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-505312ec069ddd0-20231031T065654531
# Index 4: April2022_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-387425f9b98db53-20231031T065654523
# Index 5: July2021_Data.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-cb03bbf00138398-20231031T065654559
# Index 6: Riverbed_and_Near_Surface_Water_Quality_Data_.xml
#   encoding: https://eml.ecoinformatics.org/eml-2.2.0
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-d118621673376b6-20231031T065920243
# Index 7: FLMD.csv
#   encoding: text/csv
#   url: https://data.ess-dive.lbl.gov/catalog/d1/mn/v2/object/ess-dive-0676459a454fc11-20231031T065654546

# %% [markdown]
# ### Select zip file to inspect

# %%
# Change the index at which the zip file is located 
file_index = None
try:
    file_index = file_names.index(get_string_before_first_slash(df['data_file'][dataset_index]))
except ValueError:
    print(f"'{get_string_before_first_slash(df['data_file'][index])}' is not in the datafile list.") 
    print("There was an error, move to the CSV section.")

# unzip if zip is there 
zip_file_idx = file_index
# ===================================   
fn, zip_download = inspect_zip_file_contents(dataset_detail, zip_file_idx)

print('===================================   ')
print("Desired filename:",get_string_after_first_slash(df['data_file'][dataset_index]))
# Out:
# InstallationMethods.csv is not encoded as a zip file. Please select a different file.
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[404], line 12
#      10 zip_file_idx = file_index
#      11 # ===================================
# ---> 12 fn, zip_download = inspect_zip_file_contents(dataset_detail, zip_file_idx)
#      14 print('===================================   ')
#      15 print("Desired filename:",get_string_after_first_slash(df['data_file'][dataset_index]))
#
# Cell In[392], line 234, in inspect_zip_file_contents(dataset_detail, file_idx)
#     231 fn_url = file_info.get('contentUrl')
#     232 resp = urlopen(fn_url)
# --> 234 zip_download = ZipFile(io.BytesIO(resp.read()))
#     236 print(f'{fn} contents:')
#     237 print('=================================')
#
# File ~/anaconda3/lib/python3.11/zipfile.py:1302, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1300 try:
#    1301     if mode == 'r':
# -> 1302         self._RealGetContents()
#    1303     elif mode in ('w', 'x'):
#    1304         # set the modified flag so central directory gets written
#    1305         # even if no files are added to the archive
#    1306         self._didModify = True
#
# File ~/anaconda3/lib/python3.11/zipfile.py:1369, in ZipFile._RealGetContents(self)
#    1367     raise BadZipFile("File is not a zip file")
#    1368 if not endrec:
# -> 1369     raise BadZipFile("File is not a zip file")
#    1370 if self.debug > 1:
#    1371     print(endrec)
#
# BadZipFile: File is not a zip file

# %% [markdown]
# # 4. Display file contents into a Pandas Frame

# %%
# Run if csv file is zipped up

# Change this index to the corresponding file
csv_file_index = zip_download.namelist().index(get_string_after_first_slash(df['data_file'][dataset_index]))
# If needed adjust the number of rows to skip. The Sample ID and Metadata RF specifies 1 header row.
header_rows = 0

# %% [markdown]
# ### Run this cell to see the contents of the datafile in a Dataframe.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# ===================================
csv_file_name = zip_download.namelist()[csv_file_index]
print(f'Attempting to read: {csv_file_name} from zip file {fn}')
print('=============================================================================')
 

#Idetifiers: IGSN, Sample_ID, Sample_Name, Location_ID, Site_ID, 

metadata_df = read_zipped_csv(zip_download, csv_file_name, header_rows)

if metadata_df is not None:
    is_csv_zipped = True
    headers = list(metadata_df.columns)
    display(metadata_df)
else:
    print('ERROR: Sample metadata file was not successfully loaded.')
# Out:
# Attempting to read: v2_RCSFA_Geospatial_Site_Information.csv from zip file 6_SupplementalData.zip
# =============================================================================
#          Site_ID   Latitude   Longitude                IGSN Description  \
# 0        BLU-BLU  44.162300 -122.332000  10.58052/IEWDR00WM      stream
# 1        BLU-TID  44.217900 -122.265000  10.58052/IEWDR00WN      stream
# 2           BOU1  45.644900  -73.477400  10.58052/IEWDR01BX      stream
# 3           BOU2  45.646200  -73.463700  10.58052/IEWDR01BW      stream
# 4           BOU3  45.645000  -73.452900  10.58052/IEWDR01BV      stream
# 5           BOU4  45.568500  -73.507900  10.58052/IEWDR01BO      stream
# 6           BR08  44.600600  -75.660600  10.58052/IEWDR01AQ      stream
# 7           BR09  44.634380  -75.612230  10.58052/IEWDR01AO      stream
# 8           BR11  44.790000  -75.371400  10.58052/IEWDR01AX      stream
# 9           BR12  44.846300  -75.299600  10.58052/IEWDR01AZ      stream
# 384         TRA2  46.004000  -73.175000  10.58052/IEWDR01C7      stream
# 385         TRA3  45.996900  -73.174100  10.58052/IEWDR01C6      stream
# 386      TRO-GAT  44.801195 -121.066030  10.58052/IEWDR00XO      stream
# 387          U20  46.898642 -120.642233  10.58052/IEPRS007U      stream
# 388          U22  46.907900 -120.690378  10.58052/IEPRS00V3      stream
# 389          W10  46.867453 -120.774390  10.58052/IEPRS007T      stream
# 390          W20  46.832844 -120.710935  10.58052/IEPRS007S      stream
# 391      WHY-SIS  44.287949 -121.544078  10.58052/IEWDR00XP      stream
# 392      WIL-COR  44.566361 -123.256806  10.58052/IEWDR00XQ      stream
# 393      WIL-GOS  43.980600 -122.965300  10.58052/IEWDR00XR      stream
# 394      WIL-HAR  44.270125 -123.174811  10.58052/IEWDR00XS      stream
# 395      WIL-JAS  43.998300 -122.905000  10.58052/IEWDR00XT      stream
# 396      WIL-POR  45.517500 -122.669200  10.58052/IEWDR00XU      stream
#
#                  Physiographic_Feature_Name      COMID RawCOMID_Used  \
# 0                                Blue River   23773405          True
# 1            Blue River below Tidbits Creek   23773429          True
# 2                        St. Lawrence River      -9999           NaN
# 3                        St. Lawrence River      -9999           NaN
# 4                        St. Lawrence River      -9999           NaN
# 5                        St. Lawrence River      -9999           NaN
# 6                        St. Lawrence River      -9999           NaN
# 7                        St. Lawrence River      -9999           NaN
# 8                        St. Lawrence River      -9999           NaN
# 9                        St. Lawrence River      -9999           NaN
# 10                              Brown Creek   23700569          True
# 11                              Clear Creek   24423347          True
# 12                              Clear Creek   24423347          True
# 13                              Clear Creek   24423347          True
# 14                              Clear Creek   24423347          True
# 15                       St. Lawrence River      -9999           NaN
# 16                       St. Lawrence River      -9999           NaN
# 17                       St. Lawrence River      -9999           NaN
# 18                       St. Lawrence River      -9999           NaN
# 19                       St. Lawrence River      -9999           NaN
# 20                    Clear Creek Tributary      -9999           NaN
# 21                    Clear Creek Tributary      -9999           NaN
# 22                            Bunnell Brook    6109247          True
# 23             East Branch Passumpsic River    4570659          True
# 24                         Farmington River    6109717          True
# 25                              Moose River    4570675          True
# 26                             Nepaug River    6109457          True
# 27                         Passumpsic River    4572379          True
# 28                             Phelps Brook    6109235          True
# 29                               Pope Brook    4572347          True
# 30                           Sleepers River    4572307          True
# 31                              Still River    6111419          True
# 32                        Connecticut River    7700898         False
# 33           Farmington River at Unionville    6109643          True
# 34                W-9; Pope Brook Tributary      -9999           NaN
# 35                             Cultus River   23700639          True
# 36                       St. Lawrence River      -9999           NaN
# 37                       St. Lawrence River      -9999           NaN
# 38                       St. Lawrence River      -9999           NaN
# 39                       St. Lawrence River      -9999           NaN
# 40                       St. Lawrence River      -9999           NaN
# 41          Deschutes River at Benham Falls   23700413          True
# 42               Deschutes River at La Pine   23700583          True
# 43              Deschutes River near Madras   23719673          True
# 44               Deschutes River near Biggs   23718705          True
# 45   Deschutes River below Wikiup Reservoir   23700493          True
# 46                           McKenzie River   23772789          True
# 47                           McKenzie River   23772801          True
# 48                           McKenzie River   23772909          True
# 49                               Camp Creek   23773487          True
# 50                           Hatchery Creek   23774155          True
# 51                               Gate Creek   23773469          True
# 52                               Bear Creek   23774225          True
# 53                                Elk Creek   23774923          True
# 54                              Doris Creek      -9999           NaN
# 55                               Fern Creek      -9999           NaN
# 56                             Marten Creek   23772889          True
# 57                            Lookout Creek   23773411          True
# 58                           Simmonds Creek   23773463          True
# 59                     East River at Almont    1333418          True
# 60   Bradley Creek tributary  of East River    1332190          True
# 61                    East River pump house    1332754          True
# 62       Rock Creek tributary of East River    1332198         False
# 63   Rustlers Creek tributary of East River    1332186          True
# 64       Gunnison River near Grand Junction    3232569          True
# 65             Gunnison River near Gunnison    3252665          True
# 66                Gunnison River at Road 32    3252693          True
# 67     Gunnison River below Gunnison Tunnel    3252173          True
# 68                   HJ Andrews watershed 1      -9999           NaN
# 69                   HJ Andrews watershed 2      -9999           NaN
# 70                       St. Lawrence River      -9999           NaN
# 71                       St. Lawrence River      -9999           NaN
# 72                       St. Lawrence River      -9999           NaN
# 73      Little Deschutes River near La Pine   23706200          True
# 74            Lookout Creek near Blue River   23773411          True
# 75                       St. Lawrence River      -9999           NaN
# 76                       St. Lawrence River      -9999           NaN
# 77                       St. Lawrence River      -9999           NaN
# 78                       St. Lawrence River      -9999           NaN
# 79                       St. Lawrence River      -9999           NaN
# 80                       St. Lawrence River      -9999           NaN
# 81                       St. Lawrence River      -9999           NaN
# 82                       St. Lawrence River      -9999           NaN
# 83                       St. Lawrence River      -9999           NaN
# 84                       St. Lawrence River      -9999           NaN
# 85                       St. Lawrence River      -9999           NaN
# 86                       St. Lawrence River      -9999           NaN
# 87                       St. Lawrence River      -9999           NaN
# 88                       St. Lawrence River      -9999           NaN
# 89                       St. Lawrence River      -9999           NaN
# 90                       St. Lawrence River      -9999           NaN
# 91                       St. Lawrence River      -9999           NaN
# 92                       St. Lawrence River      -9999           NaN
# 93                       St. Lawrence River      -9999           NaN
# 94                       St. Lawrence River      -9999           NaN
# 95                       St. Lawrence River      -9999           NaN
# 96                       St. Lawrence River      -9999           NaN
# 97                       St. Lawrence River      -9999           NaN
# 98          McKenzie River near Walterville   23772801          True
# 99                                New River    6908699          True
# 100                            Little River    6884184          True
# 101                             Black River    9090922          True
# 102                           Saginaw River   13204443          True
# 103                  Red River of the North    6667885          True
# 104                            Hoosic River   22290173          True
# 105                     Little Hoosic River   22290155          True
# 106                       Yellowstone River    4366016          True
# 107                           Lamprey River    5848094          True
# 108                             North River    5848106          True
# 109                        Kinderhook Creek    6186124          True
# 110                         Chocolate Bayou    1566256          True
# 111                    Lower Colorado River    5781917          True
# 112                    Lavaca River/Estuary    7843181          True
# 113                      Bear/Feather River    7972667          True
# 114                          Nooksack River   23955772          True
# 115                      South Fork Palouse   23459939          True
# 116                              Mill River    6177260          True
# 117                         Cucamonga Creek   22563070          True
# 118                  West Fork Carson River    8922013          True
# 119                              Blue River    1314635          True
# 120                          Mountain Creek    4711518         False
# 121                            Yantic River      -9999           NaN
# 122                       Pope's Head Creek   22339187          True
# 123                        Contentnea Creek   11574664          True
# 124                      St. Lawrence River      -9999           NaN
# 125                      St. Lawrence River      -9999           NaN
# 126                      St. Lawrence River      -9999           NaN
# 127                      St. Lawrence River      -9999           NaN
# 128                      St. Lawrence River      -9999           NaN
# 129                      St. Lawrence River      -9999           NaN
# 130                      St. Lawrence River      -9999           NaN
# 131                      St. Lawrence River      -9999           NaN
# 132                      St. Lawrence River      -9999           NaN
# 133                      St. Lawrence River      -9999           NaN
# 134                      St. Lawrence River      -9999           NaN
# 135                      St. Lawrence River      -9999           NaN
# 136                          American River   24422913         False
# 137                           Bumping River   24422975          True
# 138                            Quartz Creek   24423897          True
# 139            North Fork Rattlesnake Creek   24423139         False
# 140                     Little Naches River   24422831          True
# 141                       Rattlesnake Creek   24423157         False
# 142                           Bumping River   24422999          True
# 143          South Fork Little Naches River   24422871          True
# 144                          Cle Elum River   24125883          True
# 145                            Waptus River   24125945          True
# 146                             Thorp Creek   24126041          True
# 147                            Cooper River   24126011          True
# 148                            Cooper River   24125999          True
# 149                            Cooper River   24125999          True
# 150                          Cle Elum River   24125873          True
# 151                          Cle Elum River   24125873          True
# 152                West Fork Teanaway River   24125729          True
# 153               North Fork Teanaway River   24125633          True
# 154                                  Fraser      -9999           NaN
# 155                                Thompson      -9999           NaN
# 156                          South Thompson      -9999           NaN
# 157                             Assiniboine      -9999           NaN
# 158                                Dead Run   11689186          True
# 159                                Dead Run   11689186          True
# 160                                Dead Run   11689186          True
# 161                                Dead Run   11689186          True
# 162    Providence Creek / KREW's P304 creek      -9999           NaN
# 163    Providence Creek / KREW's P304 creek      -9999           NaN
# 164    Providence Creek / KREW's P304 creek      -9999           NaN
# 165    Providence Creek / KREW's P304 creek      -9999           NaN
# 166                   Teakettle T003 stream   22050323          True
# 167                   Teakettle T003 stream   22050323          True
# 168                   Teakettle T003 stream   22050323          True
# 169                   Teakettle T003 stream   22050323          True
# 170                       Little Wind River   12890609          True
# 171                       Little Wind River   12890609          True
# 172                       Little Wind River   12890609          True
# 173                       Little Wind River   12890609          True
# 174                                Altamaha   14347322          True
# 175                          Altamaha River   14347322          True
# 176                          Altamaha River   14347322          True
# 177                          Altamaha River   14347322          True
# 178                           Middle Oconee    1049671          True
# 179                               Hop Brook    7690025          True
# 180                             Posey Creek      -9999           NaN
# 181                               Lewis Run    8444872          True
# 182                             Flint River    3424530          True
# 183                            King's Creek   18841314          True
# 184                         McDiffett Creek    3649284          True
# 185                           LeConte Creek   22144520          True
# 186                           Walker Branch   22125024          True
# 187                         Tombigbee River   18548456          True
# 188                           Black Warrior   18211220          True
# 189                          Mayfield Creek   18208464          True
# 190                          Arikaree River   11722717          True
# 191                              Blue River     698676          True
# 192                           Pringle Creek    1306285          True
# 193                              Como Creek    2889452          True
# 194                    West St. Louis Creek    1239639          True
# 195                          Sycamore Creek   20440650          True
# 196                         Red Butte Creek   10389356         False
# 197                            Martha Creek   24505800          True
# 198                             McRae Creek   23773423          True
# 199                       Teakettle 2 Creek   11323962          True
# 200                               Big Creek   22048111          True
# 201                                 La Jara   17827558          True
# 202                          Marshall Gulch      -9999           NaN
# 203                                Columbia   24415028          True
# 204                        White Clay Creek    4650944          True
# 205                        White Clay Creek    4650944          True
# 206                  East Fork Poplar Creek   22125640          True
# 207                      Kings Creek (N04D)   18841358          True
# 208                           Crooked River   23713956          True
# 209                      Shark River Slough      90060          True
# 210                              Dorn Creek   13294176          True
# 211                             Huger Creek    9643259          True
# 212                  Erpe River sidechannel      -9999           NaN
# 213                      Nigardsbreen River      -9999           NaN
# 214                           Kuparuk River      -9999           NaN
# 215                             Rio Cupeyes      -9999           NaN
# 216                            Rio Guilarte      -9999           NaN
# 217                        Oksrukuyik Creek      -9999           NaN
# 218                           Caribou Creek      -9999           NaN
# 219                             Platte Kill    1748723          True
# 220                              Farmington    6109169          True
# 221                          Pamunkey River    8508050          True
# 222                      South Fork Polouse   23459937          True
# 223                                 Nakdong      -9999           NaN
# 224                             Tims Branch   22722273         False
# 225                            Jordan River      -9999           NaN
# 226                    Heel Creek tributary   23027050          True
# 227                            Yakima River  947030106          True
# 228                       Black Earth Creek   13633173          True
# 229                          Gunnison River    3252637          True
# 230                          Lower Colorado    5781919          True
# 231                           Shavers Creek    4682628          True
# 232                           Russian River    8272693          True
# 233                              Rio Grande   17819084         False
# 234                           Augusta Creek    3473077          True
# 235                     Watershed 01 stream      -9999           NaN
# 236                 North Fork Caspar Creek    2663987          True
# 237                 South Fork Caspar Creek    2665551          True
# 238                            Gordon Creek    2889384          True
# 239                           Sawmill Brook    5862611          True
# 240                              Cart Creek    5860599          True
# 241                                Columbia   24415028          True
# 242                                Columbia  947020558          True
# 243                                Columbia  947020557         False
# 244                         Cache La Poudre    2900705          True
# 245                       Little Wolf Creek   24526862          True
# 246                                  Umpqua   24526798          True
# 247                              Rio Grande   17808622          True
# ...
# 126            James Stegen        james.stegen@pnnl.gov
# 127            James Stegen        james.stegen@pnnl.gov
# 128            James Stegen        james.stegen@pnnl.gov
# 129            James Stegen        james.stegen@pnnl.gov
# 130            James Stegen        james.stegen@pnnl.gov
# 131            James Stegen        james.stegen@pnnl.gov
# 132            James Stegen        james.stegen@pnnl.gov
# 133            James Stegen        james.stegen@pnnl.gov
# 134            James Stegen        james.stegen@pnnl.gov
# 135            James Stegen        james.stegen@pnnl.gov
# 136            James Stegen        james.stegen@pnnl.gov
# 137            James Stegen        james.stegen@pnnl.gov
# 138            James Stegen        james.stegen@pnnl.gov
# 139            James Stegen        james.stegen@pnnl.gov
# 140            James Stegen        james.stegen@pnnl.gov
# 141            James Stegen        james.stegen@pnnl.gov
# 142            James Stegen        james.stegen@pnnl.gov
# 143            James Stegen        james.stegen@pnnl.gov
# 144            James Stegen        james.stegen@pnnl.gov
# 145            James Stegen        james.stegen@pnnl.gov
# 146            James Stegen        james.stegen@pnnl.gov
# 147            James Stegen        james.stegen@pnnl.gov
# 148            James Stegen        james.stegen@pnnl.gov
# 149            James Stegen        james.stegen@pnnl.gov
# 150            James Stegen        james.stegen@pnnl.gov
# 151            James Stegen        james.stegen@pnnl.gov
# 152            James Stegen        james.stegen@pnnl.gov
# 153            James Stegen        james.stegen@pnnl.gov
# 154            James Stegen        james.stegen@pnnl.gov
# 155            James Stegen        james.stegen@pnnl.gov
# 156            James Stegen        james.stegen@pnnl.gov
# 157            James Stegen        james.stegen@pnnl.gov
# 158            James Stegen        james.stegen@pnnl.gov
# 159            James Stegen        james.stegen@pnnl.gov
# 160            James Stegen        james.stegen@pnnl.gov
# 161            James Stegen        james.stegen@pnnl.gov
# 162            James Stegen        james.stegen@pnnl.gov
# 163            James Stegen        james.stegen@pnnl.gov
# 164            James Stegen        james.stegen@pnnl.gov
# 165            James Stegen        james.stegen@pnnl.gov
# 166            James Stegen        james.stegen@pnnl.gov
# 167            James Stegen        james.stegen@pnnl.gov
# 168            James Stegen        james.stegen@pnnl.gov
# 169            James Stegen        james.stegen@pnnl.gov
# 170            James Stegen        james.stegen@pnnl.gov
# 171            James Stegen        james.stegen@pnnl.gov
# 172            James Stegen        james.stegen@pnnl.gov
# 173            James Stegen        james.stegen@pnnl.gov
# 174            James Stegen        james.stegen@pnnl.gov
# 175            James Stegen        james.stegen@pnnl.gov
# 176            James Stegen        james.stegen@pnnl.gov
# 177            James Stegen        james.stegen@pnnl.gov
# 178            James Stegen        james.stegen@pnnl.gov
# 179            James Stegen        james.stegen@pnnl.gov
# 180            James Stegen        james.stegen@pnnl.gov
# 181            James Stegen        james.stegen@pnnl.gov
# 182            James Stegen        james.stegen@pnnl.gov
# 183            James Stegen        james.stegen@pnnl.gov
# 184            James Stegen        james.stegen@pnnl.gov
# 185            James Stegen        james.stegen@pnnl.gov
# 186            James Stegen        james.stegen@pnnl.gov
# 187            James Stegen        james.stegen@pnnl.gov
# 188            James Stegen        james.stegen@pnnl.gov
# 189            James Stegen        james.stegen@pnnl.gov
# 190            James Stegen        james.stegen@pnnl.gov
# 191            James Stegen        james.stegen@pnnl.gov
# 192            James Stegen        james.stegen@pnnl.gov
# 193            James Stegen        james.stegen@pnnl.gov
# 194            James Stegen        james.stegen@pnnl.gov
# 195            James Stegen        james.stegen@pnnl.gov
# 196            James Stegen        james.stegen@pnnl.gov
# 197            James Stegen        james.stegen@pnnl.gov
# 198            James Stegen        james.stegen@pnnl.gov
# 199            James Stegen        james.stegen@pnnl.gov
# 200            James Stegen        james.stegen@pnnl.gov
# 201            James Stegen        james.stegen@pnnl.gov
# 202            James Stegen        james.stegen@pnnl.gov
# 203            James Stegen        james.stegen@pnnl.gov
# 204            James Stegen        james.stegen@pnnl.gov
# 205            James Stegen        james.stegen@pnnl.gov
# 206            James Stegen        james.stegen@pnnl.gov
# 207            James Stegen        james.stegen@pnnl.gov
# 208            James Stegen        james.stegen@pnnl.gov
# 209            James Stegen        james.stegen@pnnl.gov
# 210            James Stegen        james.stegen@pnnl.gov
# 211            James Stegen        james.stegen@pnnl.gov
# 212            James Stegen        james.stegen@pnnl.gov
# 213            James Stegen        james.stegen@pnnl.gov
# 214            James Stegen        james.stegen@pnnl.gov
# 215            James Stegen        james.stegen@pnnl.gov
# 216            James Stegen        james.stegen@pnnl.gov
# 217            James Stegen        james.stegen@pnnl.gov
# 218            James Stegen        james.stegen@pnnl.gov
# 219            James Stegen        james.stegen@pnnl.gov
# 220            James Stegen        james.stegen@pnnl.gov
# 221            James Stegen        james.stegen@pnnl.gov
# 222            James Stegen        james.stegen@pnnl.gov
# 223            James Stegen        james.stegen@pnnl.gov
# 224            James Stegen        james.stegen@pnnl.gov
# 225            James Stegen        james.stegen@pnnl.gov
# 226            James Stegen        james.stegen@pnnl.gov
# 227            James Stegen        james.stegen@pnnl.gov
# 228            James Stegen        james.stegen@pnnl.gov
# 229            James Stegen        james.stegen@pnnl.gov
# 230            James Stegen        james.stegen@pnnl.gov
# 231            James Stegen        james.stegen@pnnl.gov
# 232            James Stegen        james.stegen@pnnl.gov
# 233            James Stegen        james.stegen@pnnl.gov
# 234            James Stegen        james.stegen@pnnl.gov
# 235            James Stegen        james.stegen@pnnl.gov
# 236            James Stegen        james.stegen@pnnl.gov
# 237            James Stegen        james.stegen@pnnl.gov
# 238            James Stegen        james.stegen@pnnl.gov
# 239            James Stegen        james.stegen@pnnl.gov
# 240            James Stegen        james.stegen@pnnl.gov
# 241            James Stegen        james.stegen@pnnl.gov
# 242            James Stegen        james.stegen@pnnl.gov
# 243            James Stegen        james.stegen@pnnl.gov
# 244            James Stegen        james.stegen@pnnl.gov
# 245            James Stegen        james.stegen@pnnl.gov
# 246            James Stegen        james.stegen@pnnl.gov
# 247            James Stegen        james.stegen@pnnl.gov
# 248            James Stegen        james.stegen@pnnl.gov
# 249            James Stegen        james.stegen@pnnl.gov
# 250            James Stegen        james.stegen@pnnl.gov
# 251            James Stegen        james.stegen@pnnl.gov
# 252            James Stegen        james.stegen@pnnl.gov
# 253            James Stegen        james.stegen@pnnl.gov
# 254            James Stegen        james.stegen@pnnl.gov
# 255            James Stegen        james.stegen@pnnl.gov
# 256            James Stegen        james.stegen@pnnl.gov
# 257            James Stegen        james.stegen@pnnl.gov
# 258            James Stegen        james.stegen@pnnl.gov
# 259            James Stegen        james.stegen@pnnl.gov
# 260            James Stegen        james.stegen@pnnl.gov
# 261            James Stegen        james.stegen@pnnl.gov
# 262            James Stegen        james.stegen@pnnl.gov
# 263            James Stegen        james.stegen@pnnl.gov
# 264            James Stegen        james.stegen@pnnl.gov
# 265            James Stegen        james.stegen@pnnl.gov
# 266            James Stegen        james.stegen@pnnl.gov
# 267            James Stegen        james.stegen@pnnl.gov
# 268            James Stegen        james.stegen@pnnl.gov
# 269            James Stegen        james.stegen@pnnl.gov
# 270            James Stegen        james.stegen@pnnl.gov
# 271            James Stegen        james.stegen@pnnl.gov
# 272            James Stegen        james.stegen@pnnl.gov
# 273            James Stegen        james.stegen@pnnl.gov
# 274            James Stegen        james.stegen@pnnl.gov
# 275            James Stegen        james.stegen@pnnl.gov
# 276            James Stegen        james.stegen@pnnl.gov
# 277            James Stegen        james.stegen@pnnl.gov
# 278            James Stegen        james.stegen@pnnl.gov
# 279            James Stegen        james.stegen@pnnl.gov
# 280            James Stegen        james.stegen@pnnl.gov
# 281            James Stegen        james.stegen@pnnl.gov
# 282            James Stegen        james.stegen@pnnl.gov
# 283            James Stegen        james.stegen@pnnl.gov
# 284            James Stegen        james.stegen@pnnl.gov
# 285            James Stegen        james.stegen@pnnl.gov
# 286            James Stegen        james.stegen@pnnl.gov
# 287            James Stegen        james.stegen@pnnl.gov
# 288            James Stegen        james.stegen@pnnl.gov
# 289            James Stegen        james.stegen@pnnl.gov
# 290            James Stegen        james.stegen@pnnl.gov
# 291            James Stegen        james.stegen@pnnl.gov
# 292            James Stegen        james.stegen@pnnl.gov
# 293            James Stegen        james.stegen@pnnl.gov
# 294            James Stegen        james.stegen@pnnl.gov
# 295            James Stegen        james.stegen@pnnl.gov
# 296            James Stegen        james.stegen@pnnl.gov
# 297            James Stegen        james.stegen@pnnl.gov
# 298            James Stegen        james.stegen@pnnl.gov
# 299            James Stegen        james.stegen@pnnl.gov
# 300            James Stegen        james.stegen@pnnl.gov
# 301            James Stegen        james.stegen@pnnl.gov
# 302            James Stegen        james.stegen@pnnl.gov
# 303            James Stegen        james.stegen@pnnl.gov
# 304            James Stegen        james.stegen@pnnl.gov
# 305            James Stegen        james.stegen@pnnl.gov
# 306            James Stegen        james.stegen@pnnl.gov
# 307            James Stegen        james.stegen@pnnl.gov
# 308            James Stegen        james.stegen@pnnl.gov
# 309            James Stegen        james.stegen@pnnl.gov
# 310            James Stegen        james.stegen@pnnl.gov
# 311            James Stegen        james.stegen@pnnl.gov
# 312            James Stegen        james.stegen@pnnl.gov
# 313            James Stegen        james.stegen@pnnl.gov
# 314            James Stegen        james.stegen@pnnl.gov
# 315            James Stegen        james.stegen@pnnl.gov
# 316            James Stegen        james.stegen@pnnl.gov
# 317            James Stegen        james.stegen@pnnl.gov
# 318            James Stegen        james.stegen@pnnl.gov
# 319            James Stegen        james.stegen@pnnl.gov
# 320            James Stegen        james.stegen@pnnl.gov
# 321            James Stegen        james.stegen@pnnl.gov
# 322            James Stegen        james.stegen@pnnl.gov
# 323            James Stegen        james.stegen@pnnl.gov
# 324            James Stegen        james.stegen@pnnl.gov
# 325            James Stegen        james.stegen@pnnl.gov
# 326            James Stegen        james.stegen@pnnl.gov
# 327            James Stegen        james.stegen@pnnl.gov
# 328            James Stegen        james.stegen@pnnl.gov
# 329            James Stegen        james.stegen@pnnl.gov
# 330            James Stegen        james.stegen@pnnl.gov
# 331            James Stegen        james.stegen@pnnl.gov
# 332            James Stegen        james.stegen@pnnl.gov
# 333            James Stegen        james.stegen@pnnl.gov
# 334            James Stegen        james.stegen@pnnl.gov
# 335            James Stegen        james.stegen@pnnl.gov
# 336            James Stegen        james.stegen@pnnl.gov
# 337            James Stegen        james.stegen@pnnl.gov
# 338            James Stegen        james.stegen@pnnl.gov
# 339            James Stegen        james.stegen@pnnl.gov
# 340            James Stegen        james.stegen@pnnl.gov
# 341            James Stegen        james.stegen@pnnl.gov
# 342            James Stegen        james.stegen@pnnl.gov
# 343            James Stegen        james.stegen@pnnl.gov
# 344            James Stegen        james.stegen@pnnl.gov
# 345            James Stegen        james.stegen@pnnl.gov
# 346            James Stegen        james.stegen@pnnl.gov
# 347            James Stegen        james.stegen@pnnl.gov
# 348            James Stegen        james.stegen@pnnl.gov
# 349            James Stegen        james.stegen@pnnl.gov
# 350            James Stegen        james.stegen@pnnl.gov
# 351            James Stegen        james.stegen@pnnl.gov
# 352            James Stegen        james.stegen@pnnl.gov
# 353            James Stegen        james.stegen@pnnl.gov
# 354            James Stegen        james.stegen@pnnl.gov
# 355            James Stegen        james.stegen@pnnl.gov
# 356            James Stegen        james.stegen@pnnl.gov
# 357            James Stegen        james.stegen@pnnl.gov
# 358            James Stegen        james.stegen@pnnl.gov
# 359            James Stegen        james.stegen@pnnl.gov
# 360            James Stegen        james.stegen@pnnl.gov
# 361            James Stegen        james.stegen@pnnl.gov
# 362            James Stegen        james.stegen@pnnl.gov
# 363            James Stegen        james.stegen@pnnl.gov
# 364            James Stegen        james.stegen@pnnl.gov
# 365            James Stegen        james.stegen@pnnl.gov
# 366            James Stegen        james.stegen@pnnl.gov
# 367            James Stegen        james.stegen@pnnl.gov
# 368            James Stegen        james.stegen@pnnl.gov
# 369            James Stegen        james.stegen@pnnl.gov
# 370            James Stegen        james.stegen@pnnl.gov
# 371            James Stegen        james.stegen@pnnl.gov
# 372            James Stegen        james.stegen@pnnl.gov
# 373            James Stegen        james.stegen@pnnl.gov
# 374            James Stegen        james.stegen@pnnl.gov
# 375            James Stegen        james.stegen@pnnl.gov
# 376            James Stegen        james.stegen@pnnl.gov
# 377            James Stegen        james.stegen@pnnl.gov
# 378            James Stegen        james.stegen@pnnl.gov
# 379            James Stegen        james.stegen@pnnl.gov
# 380            James Stegen        james.stegen@pnnl.gov
# 381            James Stegen        james.stegen@pnnl.gov
# 382            James Stegen        james.stegen@pnnl.gov
# 383            James Stegen        james.stegen@pnnl.gov
# 384            James Stegen        james.stegen@pnnl.gov
# 385            James Stegen        james.stegen@pnnl.gov
# 386            James Stegen        james.stegen@pnnl.gov
# 387      Allison Myers-Pigg  allison.myers-pigg@pnnl.gov
# 388      Allison Myers-Pigg  allison.myers-pigg@pnnl.gov
# 389      Allison Myers-Pigg  allison.myers-pigg@pnnl.gov
# 390      Allison Myers-Pigg  allison.myers-pigg@pnnl.gov
# 391            James Stegen        james.stegen@pnnl.gov
# 392            James Stegen        james.stegen@pnnl.gov
# 393            James Stegen        james.stegen@pnnl.gov
# 394            James Stegen        james.stegen@pnnl.gov
# 395            James Stegen        james.stegen@pnnl.gov
# 396            James Stegen        james.stegen@pnnl.gov

# %% [markdown]
# ### Select specific colums to display

# %%
# Enter column indices from above
metadata_columns_idxs = [0, 1, 2, 3,]

# ===================================

display(metadata_df.iloc[:, metadata_columns_idxs])
print('==============================')
for col_idx in metadata_columns_idxs:
    print(f'Index {col_idx} --- {headers[col_idx]}')
# Out:
#          Site_ID   Latitude   Longitude                IGSN
# 0        BLU-BLU  44.162300 -122.332000  10.58052/IEWDR00WM
# 1        BLU-TID  44.217900 -122.265000  10.58052/IEWDR00WN
# 2           BOU1  45.644900  -73.477400  10.58052/IEWDR01BX
# 3           BOU2  45.646200  -73.463700  10.58052/IEWDR01BW
# 4           BOU3  45.645000  -73.452900  10.58052/IEWDR01BV
# 367          T42  46.728950 -120.714310  10.58052/IEPRS0096
# 368      TAY-RES  38.818300 -106.608600  10.58052/IEWDR00XM
# 369      TAY-TAY  38.860400 -106.567000  10.58052/IEWDR00XN
# 370         TCL1  45.665600  -73.464400  10.58052/IEWDR01BP
# 371         TCM1  45.706900  -73.478700  10.58052/IEWDR01BT
# 372       TCM1.5  45.589400  -73.497300  10.58052/IEWDR01BQ
# 373         TCM2  45.705100  -73.455600  10.58052/IEWDR01BS
# 374       TCM2.5  45.675800  -73.458000  10.58052/IEWDR01BR
# 375         TCM3  45.703800  -73.444700  10.58052/IEWDR01BU
# 376        THI01  44.213200  -76.545700  10.58052/IEWDR01AS
# 377        THI02  44.240240  -76.418030  10.58052/IEWDR01AU
# 378        THI03  44.259300  -76.378400  10.58052/IEWDR01AV
# 379        THI04  44.303400  -76.196900  10.58052/IEWDR01AT
# 380        THI05  44.323200  -76.166800  10.58052/IEWDR01AP
# 381        THI06  44.324400  -76.159000  10.58052/IEWDR01AN
# 382        THI07  44.484000  -75.826800  10.58052/IEWDR01AR
# 383         TRA1  45.996600  -73.187300  10.58052/IEWDR01C5
# 384         TRA2  46.004000  -73.175000  10.58052/IEWDR01C7
# 385         TRA3  45.996900  -73.174100  10.58052/IEWDR01C6
# 386      TRO-GAT  44.801195 -121.066030  10.58052/IEWDR00XO
# 387          U20  46.898642 -120.642233  10.58052/IEPRS007U
# 388          U22  46.907900 -120.690378  10.58052/IEPRS00V3
# 389          W10  46.867453 -120.774390  10.58052/IEPRS007T
# 390          W20  46.832844 -120.710935  10.58052/IEPRS007S
# 391      WHY-SIS  44.287949 -121.544078  10.58052/IEWDR00XP
# 392      WIL-COR  44.566361 -123.256806  10.58052/IEWDR00XQ
# 393      WIL-GOS  43.980600 -122.965300  10.58052/IEWDR00XR
# 394      WIL-HAR  44.270125 -123.174811  10.58052/IEWDR00XS
# 395      WIL-JAS  43.998300 -122.905000  10.58052/IEWDR00XT
# 396      WIL-POR  45.517500 -122.669200  10.58052/IEWDR00XU
# ==============================
# Index 0 --- Site_ID
# Index 1 --- Latitude
# Index 2 --- Longitude
# Index 3 --- IGSN

# %% [markdown]
# # 5. Download
# <b> Run steps 3 and 4 before downlodind
#
# Download files that are interesting
#
# Look at the data download `encodingFormat` to see if it is a zip (application/zip) file or a csv (text/csv)

# %%
# ===================================
if not is_csv_zipped:
    fn = csv_index[metadata_file_idx]
    all_file_idx = None

    for idx, filename in enumerate(dataset_detail.get('distribution')):
        if filename.get('name') == fn:
            all_file_idx = idx
            break
    if all_file_idx:
        ds_doi = download_selected_files(dataset_detail, [all_file_idx], local_dir)
    else:
        print('Could not find requested file.')
else:
    ds_doi = download_selected_files(dataset_detail, [zip_file_idx], local_dir, is_csv_zipped=is_csv_zipped, 
                                     zip_download=zip_download, zip_member_fn=csv_file_name)
# Out:
# Saving files in /Users/YLH/ESS-DIVE/essdive-tutorials/downloads
# -------------------------------------
# --- 6_SupplementalData.zip downloaded
# -------------------------------------
# Remember to cite these files! Dataset DOI doi:10.15485/1999774

# %% [markdown]
# End of Tutorial
